# %%
import re
import spacy
word_regex = r'[\w]+'

# %%
book_vectors = []
nlp_en = spacy.load('en')
nlp_ru = spacy.load('ru')
with open("library_input.txt", "r") as file:
    N = int(file.readline())
    for i in range(1, N + 1):
        books.append(file.readline().rstrip())

print(books[:100])
max_words = -1
for book in books:
    words = re.findall(word_regex, book, re.U)
    if len(words) > max_words:
        max_words = len(words)
print(max_words)
# Out:
# ['Восхождение фениксов', 'Мятежная королева', 'Солнечные зайчики', 'Школа безумия', 'Не мой Ромео', 'Леди в озере', 'Хорошая компания', 'Оставь мир позади', 'Новая девушка', 'От первого лица', 'Благословение небожителей. Том 6', 'Семь или восемь смертей Стеллы Фортуны', 'Валенсия и Валентайн', 'Верность', 'Космология монстров', 'Поднятие уровня в одиночку. Solo Leveling. Книга 3', 'Освобождение', 'Nomen nescio. Имя неизвестно', 'Элджернон, Чарли и я', 'Глядя на море', 'Братья. Книга 3. Завтрашний царь. Том 1', 'Bromance. Книжный клуб спешит на помощь', 'Никто не видел Мандей', 'Американский хищник', 'Четвертое крыло', 'Зацепить 13-го', 'Тайны призраков', 'Цирк чудес', 'Благословение небожителей. Том 5', 'Удушающая сладость, заиндевелый пепел. Книга 2', 'Я подарю тебе крылья. Лимитированное издание трилогии', 'Система «Спаси-себя-сам» для главного злодея', 'Супермаркет', 'Вечность и Тлен', 'Драгоценная ты', 'Последние часы. Книга III. Терновая цепь', 'Шах и мат', 'Женщина в бегах', 'К
# ...
